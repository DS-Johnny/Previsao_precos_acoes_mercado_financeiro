# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Função para gerar o gráfico com base nas opções escolhidas
def plot_graph(ticket, period, interval):
    dados = yf.download(ticket, period=period, interval=interval)

    # Remover finais de semana e feriados (dias sem negociação)
    dados = dados.dropna()

    # Criar gráfico
    plt.figure(figsize=(10, 6))
    plt.plot(dados.index, dados['Close'], label=f'Cotação de Fechamento ({interval})')

    plt.title(f'Cotação de {ticket} ({period})')
    plt.xlabel('Data')
    plt.ylabel('Preço de Fechamento (R$)')
    plt.xticks(rotation=45)

    # Formatar e ajustar o eixo X para datas
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d-%m-%Y'))  # Formato das datas
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator())  # Mostrar apenas dias úteis (semanas)

    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Solicitar parâmetros ao usuário
ticket = input("Digite o ticker da ação (ex: VALE3.SA): ")
period = input("Digite o período (opções: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max): ")
interval = input("Digite o intervalo (opções: 1m, 5m, 15m, 30m, 60m, 90m, 1d, 5d, 1wk, 1mo, 3mo): ")

# Gerar o gráfico com os parâmetros informados
plot_graph(ticket, period, interval)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# !py -m pip show yfinance
# Out:
# Name: yfinance
# Version: 0.2.43
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: C:\Users\Johnny\Desktop\UNIVESP\PI4\pi4_env\Lib\site-packages
# Requires: beautifulsoup4, frozendict, html5lib, lxml, multitasking, numpy, pandas, peewee, platformdirs, pytz, requests
# Required-by:

# %%
# Web Scraping 

# Lista original como uma única string
ROE = "23,72%	20,91%	51,27%	63,01%	15,16%	-4,37%	15,06%	12,26%	10,46%	-33,81%	0,65%"

# Separar a string em uma lista de valores
ROE_lista = ROE.split("\t")

# Remover o símbolo '%' e converter os valores para float
ROE_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in ROE_lista]

# Inverter a lista usando fatiamento
ROE_numerico = ROE_numerico[::-1]

# Exibindo a nova lista
print("Valores de ROE sem '%':", ROE_numerico)
# Out:
# Valores de ROE sem '%': [0.65, -33.81, 10.46, 12.26, 15.06, -4.37, 15.16, 63.01, 51.27, 20.91, 23.72]

# %%
# Web Scraping 

# Lista original como uma única string
ROIC = "22,11%	19,46%	29,65%	43,08%	19,31%	-0,13%	18,33%	13,72%	5,01%	-19,70%	7,70%"

# Separar a string em uma lista de valores
ROIC_lista = ROIC.split("\t")

# Remover o símbolo '%' e converter os valores para float
ROIC_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in ROIC_lista]

# Inverter a lista usando fatiamento
ROIC_numerico = ROIC_numerico[::-1]

# Exibindo a nova lista
print("Valores de ROIC sem '%':", ROIC_numerico)
# Out:
# Valores de ROIC sem '%': [7.7, -19.7, 5.01, 13.72, 18.33, -0.13, 19.31, 43.08, 29.65, 19.46, 22.11]

# %%
# Web Scraping 

# Lista original como uma única string
ROA	= "10,17%	8,89%	21,25%	24,33%	5,21%	-2,35%	7,53%	5,39%	4,12%	-13,31%	0,07%"

# Separar a string em uma lista de valores
ROA_lista = ROA.split("\t")

# Remover o símbolo '%' e converter os valores para float
ROA_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in ROA_lista]

# Inverter a lista usando fatiamento
ROA_numerico = ROA_numerico[::-1]

# Exibindo a nova lista
print("Valores de ROA sem '%':", ROA_numerico)
# Out:
# Valores de ROA sem '%': [0.07, -13.31, 4.12, 5.39, 7.53, -2.35, 5.21, 24.33, 21.25, 8.89, 10.17]

# %%
import matplotlib.pyplot as plt

# web scraping 
anos = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, "Atual"]
roe = [0.65, -33.81, 10.46, 12.26, 15.06, -4.37, 15.16, 63.01, 51.27, 20.91, 23.72]
roic = [7.7, -19.7, 5.01, 13.72, 18.33, -0.13, 19.31, 43.08, 29.65, 19.46, 22.11]
roa = [0.07, -13.31, 4.12, 5.39, 7.53, -2.35, 5.21, 24.33, 21.25, 8.89, 10.17]




# Criação do gráfico
plt.figure(figsize=(10, 6))

# Plotar ROE
plt.plot(anos, roe, marker='o', label='ROE', color='b')

# Plotar ROIC
plt.plot(anos, roic, marker='s', label='ROIC', color='g')

# Plotar ROA
plt.plot(anos, roa, marker='^', label='ROA', color='r')

# Adicionar título e legendas
plt.title('ROE, ROIC e ROA ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Percentual (%)')
plt.legend()

# Exibir o gráfico
plt.grid(True)
plt.show()

# %%
import pandas as pd
import plotly_express as px
ws = {'Anos' : [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
      'ROE' : [0.65, -33.81, 10.46, 12.26, 15.06, -4.37, 15.16, 63.01, 51.27, 20.91, 23.72],
      'ROIC' : [7.7, -19.7, 5.01, 13.72, 18.33, -0.13, 19.31, 43.08, 29.65, 19.46, 22.11],
      'ROA' : [0.07, -13.31, 4.12, 5.39, 7.53, -2.35, 5.21, 24.33, 21.25, 8.89, 10.17]
      }

df = pd.DataFrame(ws)
df
# Out:
#     Anos    ROE   ROIC    ROA
# 0   2014   0.65   7.70   0.07
# 1   2015 -33.81 -19.70 -13.31
# 2   2016  10.46   5.01   4.12
# 3   2017  12.26  13.72   5.39
# 4   2018  15.06  18.33   7.53
# 5   2019  -4.37  -0.13  -2.35
# 6   2020  15.16  19.31   5.21
# 7   2021  63.01  43.08  24.33
# 8   2022  51.27  29.65  21.25
# 9   2023  20.91  19.46   8.89
# 10  2024  23.72  22.11  10.17

# %%
fig = px.line(df, 'Anos', y=['ROE', 'ROIC', 'ROA'])

# %%
# Web Scraping

# Lista original como uma única string
divida_liquida_ebitda = "0,56	0,62	0,36	0,07	0,11	1,78	0,67	1,36	2,81	-6,1	2,48"

# Separar a string em uma lista de valores
divida_liquida_ebitda_lista = divida_liquida_ebitda.split("\t")

# Remover o símbolo '%' e converter os valores para float
divida_liquida_ebitda_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in divida_liquida_ebitda_lista]

# Inverter a lista usando fatiamento
divida_liquida_ebitda = divida_liquida_ebitda_numerico[::-1]

# Exibindo a nova lista
print("Valores de divida_liquida_ebitda sem '%':", divida_liquida_ebitda)
# Out:
# Valores de divida_liquida_ebitda sem '%': [2.48, -6.1, 2.81, 1.36, 0.67, 1.78, 0.11, 0.07, 0.36, 0.62, 0.56]

# %%
# Web Scraping 

# Lista original como uma única string
divida_bruta_patrimonio = "0,41	0,35	0,35	0,4	0,44	0,39	0,35	0,52	0,75	0,86	0,52"

# Separar a string em uma lista de valores
divida_bruta_patrimonio_lista = divida_bruta_patrimonio.split("\t")

# Remover o símbolo '%' e converter os valores para float
divida_bruta_patrimonio_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in divida_bruta_patrimonio_lista]

# Inverter a lista usando fatiamento
divida_bruta_patrimonio = divida_bruta_patrimonio_numerico[::-1]

# Exibindo a nova lista
print("Valores de divida_bruta_patrimonio sem '%':", divida_bruta_patrimonio)
# Out:
# Valores de divida_bruta_patrimonio sem '%': [0.52, 0.86, 0.75, 0.52, 0.35, 0.39, 0.44, 0.4, 0.35, 0.35, 0.41]

# %%
import matplotlib.pyplot as plt

# Web Scraping 
anos = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
divida_bruta_patrimonio = [0.52, 0.86, 0.75, 0.52, 0.35, 0.39, 0.44, 0.4, 0.35, 0.35, 0.41]
divida_liquida_ebitda = [2.48, -6.1, 2.81, 1.36, 0.67, 1.78, 0.11, 0.07, 0.36, 0.62, 0.56] 

# Criação do gráfico
plt.figure(figsize=(10, 6))

# Plotar Dívida Líquida/EBITDA
plt.plot(anos, divida_liquida_ebitda, marker='o', label='Dívida Líquida/EBITDA', color='b')

# Plotar Dívida Bruta/Patrimônio
plt.plot(anos, divida_bruta_patrimonio, marker='s', label='Dívida Bruta/Patrimônio', color='g')

# Adicionar título e legendas
plt.title('Dívida Líquida/EBITDA e Dívida Bruta/Patrimônio')
plt.xlabel('Ano')
plt.ylabel('Valor')
plt.legend()

# Exibir o gráfico
plt.grid(True)
plt.show()

# %%
grafico_3 = {"anos" : [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
            "divida_bruta_patrimonio" : [0.52, 0.86, 0.75, 0.52, 0.35, 0.39, 0.44, 0.4, 0.35, 0.35, 0.41],
            "divida_liquida_ebitda" : [2.48, -6.1, 2.81, 1.36, 0.67, 1.78, 0.11, 0.07, 0.36, 0.62, 0.56]}

g3 = pd.DataFrame(grafico_3)
px.line(g3, x='anos', y=['divida_bruta_patrimonio', 'divida_liquida_ebitda'])

# %%
# Web Scraping 

# Lista original como uma única string
dy = "11,47%	7,87%	8,53%	18,79%	2,75%	2,65%	3,86%	3,29%	0,65%	7,49%	8,62%"

# Separar a string em uma lista de valores
dy_lista = dy.split("\t")

# Remover o símbolo '%' e converter os valores para float
dy_numerico = [float(valor.replace(",", ".").replace("%", "")) for valor in dy_lista]

# Inverter a lista usando fatiamento
dy_numerico = dy_numerico[::-1]

# Exibindo a nova lista
print("Valores de dy sem '%':", dy_numerico)
# Out:
# Valores de dy sem '%': [8.62, 7.49, 0.65, 3.29, 3.86, 2.65, 2.75, 18.79, 8.53, 7.87, 11.47]

# %%
import matplotlib.pyplot as plt

# Dados
tempo = "Atual\t2023\t2022\t2021\t2020\t2019\t2018\t2017\t2016\t2015\t2014"

# Transformando os dados em listas
anos = tempo.split("\t")

# Criar gráfico
plt.figure(figsize=(10, 6))
plt.plot(anos[::-1], dy_numerico, marker='o', color='blue', label='Dividend Yield (DY)')

# Adicionar título e legendas
plt.title('Dividend Yield (DY) ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Dividend Yield (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
g4 = {"dy_numerico" : [8.62, 7.49, 0.65, 3.29, 3.86, 2.65, 2.75, 18.79, 8.53, 7.87, 11.47],
        "anos" : [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]}

g4 = pd.DataFrame(g4)
px.line(g4, x='anos', y='dy_numerico')

# %%
tabela = pd.read_excel('Vale3_2024_10_17.xlsx')
tabela[['VALE3', 'Atual']]
# Out:
#                         VALE3   Atual
# 0                         ROE  0.2372
# 1                         ROA  0.1017
# 2                        ROIC  0.2211
# 3              MARGEM LÍQUIDA  0.2319
# 4                MARGEM BRUTA  0.4066
# 5               MARGEM EBITDA  0.4084
# 6                         P/L    5.87
# 7                        P/VP    1.39
# 8                   EV/EBITDA    3.89
# 9                     EV/EBIT    4.76
# 10        DIVIDEND YIELD (DY)  0.1147
# 11    DÍVIDA LÍQUIDA / EBITDA    0.56
# 12  DÍVIDA BRUTA / PATRIMÔNIO    0.41
# 13          LIQUIDEZ CORRENTE    1.08
# 14                GIRO ATIVOS    0.44
# 15                     PAYOUT  0.6673
# 16       CAGR RECEITAS 5 ANOS  0.0717
# 17            P/RECEITA (PSR)    1.36
# 18                MARGEM EBIT  0.3336
# 19                   P/EBITDA    3.34
# 20                     P/EBIT    4.08
# 21                    P/ATIVO    0.59
# 22                 P/CAP.GIRO   47.31
# 23           P/ATIVO CIRC LIQ   -0.72
# ...

# %%
modelos = {'ML1' : 'Compra', 
           'ML2' : 'Compra', 
           'ML3' : 'Venda'}

modelos = pd.DataFrame(modelos, index=[0,1,2])
modelos
# Out:
#       ML1     ML2    ML3
# 0  Compra  Compra  Venda
# 1  Compra  Compra  Venda
# 2  Compra  Compra  Venda
